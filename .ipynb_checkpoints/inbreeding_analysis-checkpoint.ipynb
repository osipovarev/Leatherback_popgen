# %%
#!/Users/osipova/miniconda3/envs/py13/bin/pip3 install statsmodels

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib
import statsmodels.stats.multitest as smt
from scipy.stats import mannwhitneyu, ttest_ind
from os.path import join
from glob import glob
import warnings
import logging

## regression; glm
from scipy.stats import linregress
import statsmodels.formula.api as smf
import statsmodels.api as sm
from scipy.special import expit
from statsmodels.genmod.families import Gamma, NegativeBinomial, Binomial
## spearman correlation
from scipy.stats import spearmanr

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['figure.dpi'] = 100
warnings.filterwarnings("ignore")

# %%
def load_sample_info(file_path):
    df = pd.read_csv(file_path, sep='\t')[[
        'sample_ID', 'rookery-region', 'Year', 'group-Lkadj',
        'Management units - based on DNA', 'Post_dupe_depth_2_all_LKGATK_USE',
        'Exclude-all_GL_ROH_analyses', 'Sequencing_source-type', 'Stage_Class', 
        'Include temporal analysis', 'Temporal Generation'
    ]]
    return df.rename(columns={
        'sample_ID': 'sample',
        'rookery-region': 'rookery',
        'Year': 'year',
        'group-Lkadj': 'group',
        'Management units - based on DNA': 'MU',
        'Post_dupe_depth_2_all_LKGATK_USE': 'depth',
        'Exclude-all_GL_ROH_analyses': 'exclude',
        'Include temporal analysis': 'temporal',
        'Temporal Generation': 'generation',
        'Sequencing_source-type': 'batch',
        'Stage_Class': 'stage'
    })

# %%
pop_order = ['larger_declining', 'small_stable', 'small_declining', 
             'larger_stable', 'small_recovering']

# %% [markdown]
# # 0. Load location and groupings information

# %%
dir_path = '/Users/osipova/Documents/LabDocs/Leatherback_popgen/'
file_name = 'dc_222_samples_info.tsv'
file_data = glob(join(dir_path, file_name))[0]
INFO = load_sample_info(file_data)

# %% [markdown]
# ## 0.1. Define colors

# %%
rookery_palette_dict = {
    'Mexico': '#1f77b4',
    'Atl Costa Rica': '#005a32',
    'Indonesia': '#d62728',
    'Pacific Costa Rica': '#7570b3',
    'Papua New Guinea': '#dd3497',
    'Solomon Islands': '#fde0dd',
    'Malaysia': '#2ca02c',
    'South Africa': '#17becf',
    'Ghana': '#ff7f0e',
    'Gabon': '#fdd0a2',
    'French Guiana-Suriname': '#8c564b',
    'Virgin Islands': '#d6eaf8',
    'Florida': '#d9f0a3',
    'na': '#000000',
    'unknown': '#7f7f7f'}

mu_palette_dict = {
    'Eastern Pacific': '#1f77b4',
    'Western Pacific': '#d62728',
    'Northwest Caribbean': '#005a32',
    'Northeast Caribbean': '#6a51a3',
    'Northern Caribbean': '#d9f0a3',
    'South Africa': '#17becf',
    'SE Atlantic/West Africa': '#ff7f0e',
    'South-east Caribbean': '#8c564b',
    'Indo-Western Pacific': '#2ca02c',
    'na': '#000000',
    'unknown': '#7f7f7f'}

batch_palette_dict = {
    'novo_UMass_Illumina_SR': '#1f77b4',
    'novo42_Illumina_SR': '#ff7f0e',
    'LR-getinfofromJH': '#2ca02c',
    'Duffy_Illumina_SR': '#d62728'}

population_palette_dict = {
    'larger_declining': '#d62728',
    'small_stable':'#1f77b4',
    'small_declining': '#005a32',
    'larger_stable': '#ff7f0e',
    'small_recovering': '#6a51a3'}

# %% [markdown]
# ## Funcition 0: regression

# %%
def plot_regression(
    ax, df, group_col, x, y, palette=None, annotate_pvalue=True, alpha=1.0):
    """
    Returns a dataframe of regression statistics.
    """
    stats_results = []
    unique_groups = df[group_col].unique()
    for group in unique_groups:
        subdf = df[df[group_col] == group]
        
        slope, intercept, r_value, p_value, std_err = linregress(subdf[x], subdf[y])
        r2 = r_value ** 2

        stats_results.append({
            'group': group,
            'slope': slope,
            'intercept': intercept,
            'r': r_value,
            'r2': r2,
            'pvalue': p_value,
            'stderr': std_err})
        
        color = palette[group] if palette and group in palette else None
        
        p_thresh = 1
        if p_value < p_thresh:
            # Plot regression line
            xvals = subdf[x].sort_values()
            y_pred = intercept + slope * xvals
            ax.plot(xvals, y_pred, color=color, 
                    linestyle='-', lw=2, alpha=alpha,
                    label=f"{group} reg")

        if annotate_pvalue and p_value < p_thresh:
            maxy = subdf[y].max()
            midx = subdf[x].median()
            ax.text(midx, maxy, f'p = {p_value:.2e} r2 = {r2:.2f}', ha='center', va='bottom', fontsize=9)
    return pd.DataFrame(stats_results)

# %%
def plot_glm(
    ax, df, group_col, x, y, palette=None, annotate_pvalue=True, alpha=1.0
):
    """
    Run a GLM for each group: y ~ x + C(stage).
    Annotate plot with p-values for both year (x) and stage.
    Returns a dataframe of regression statistics.
    """
    stats_results = []
    unique_groups = df[group_col].unique()

    for group in unique_groups:
        subdf = df[df[group_col] == group].copy()

        # Fit model
        if y == 'F_ROH':
            # logit-transform F_ROH
            eps = 1e-6
            tmp = subdf.copy()
            clipped = tmp[y].clip(eps, 1 - eps)
            tmp['_y'] = np.log(clipped / (1 - clipped))  # logit
            model = smf.glm(f"_y ~ {x} + C(stage)", data=tmp).fit()

        else:
            model = smf.glm(f"{y} ~ {x} + C(stage)", data=subdf).fit()

        # Extract coefficients
        slope_year = model.params.get(x, np.nan)
        p_year = model.pvalues.get(x, np.nan)

        stage_terms = {name: p for name, p in model.pvalues.items()
            if "stage" in name and name not in ("Intercept", x)}

        stats_entry = {
            "group": group,
            "slope_year": slope_year,
            "p_year": p_year}
        
        # Add stage p-values
        for term, p in stage_terms.items():
            stats_entry[f"p_{term}"] = p

        stats_results.append(stats_entry)

        # Color choice
        color = palette[group] if palette and group in palette else None

        xvals = np.linspace(subdf[x].min(), subdf[x].max(), 100)
        pred_df = pd.DataFrame({x: xvals})

        if 'stage' in subdf.columns:
            pred_df['stage'] = subdf['stage'].mode()[0]

        pred = model.get_prediction(pred_df)
        pred_mean = pred.predicted_mean
        ci = pred.conf_int()
        lower = ci[:, 0]
        upper = ci[:, 1]

        if y == 'F_ROH':
            # inverse logit: mapped to probability scale
            pred_mean = expit(pred_mean)
            lower = expit(lower)
            upper = expit(upper)

        # Plot regression line
        ax.plot(xvals, pred_mean, color=color, lw=2, alpha=alpha, label=f"{group} reg")

        # Plot CI
        ax.fill_between(xvals, lower, upper, color=color, alpha=0.06)

        # Annotate p-values
        if annotate_pvalue:
            maxy = subdf[y].max()
            miny = subdf[y].min()
            midx = subdf[x].median()

            ax.text(midx, maxy,f"p({x})={p_year:.2e}", ha="center", va="bottom", fontsize=10, color=color)

            y_range = maxy - miny if maxy != miny else 1.0
            y_offset = y_range * 0.08

            for i, (term, p) in enumerate(stage_terms.items()):
                ax.text(
                    midx, maxy - (i + 1) * y_offset,
                    f"p({term})={p:.2e}",
                    ha="center", va="bottom", fontsize=9, color=color)

    return pd.DataFrame(stats_results)

# %%
def test_trend(df, x_col, y_col, eps=1e-4):
    """
    Spearman trend + appropriate GLM depending on ROH metric.
    Uses fractional logit for F_ROH.
    """

    sub = df[[x_col, y_col]].dropna()

    x = sub[x_col].astype(float)
    y = sub[y_col].astype(float)

    # -----------------
    # Spearman
    # -----------------
    rho, spearman_p = spearmanr(x, y)

    # -----------------
    # Choose GLM
    # -----------------
    if y_col == "F_ROH":
        # Fractional logit
        y_glm = y.clip(eps, 1 - eps)
        family = Binomial(link=sm.genmod.families.links.logit())
        model_name = "logit Binomial"

    elif y_col == "number_ROH":
        # Count data
        y_glm = y
        family = NegativeBinomial()
        model_name = "Negative Binomial"

    else:
        # Positive, skewed continuous
        y_glm = y
        family = Gamma(link=sm.genmod.families.links.log())
        model_name = "Gamma"

    # -----------------
    # Fit GLM
    # -----------------
    X = sm.add_constant(x)
    model = sm.GLM(y_glm, X, family=family).fit()

    slope = model.params[x_col]
    slope_p = model.pvalues[x_col]

    return pd.DataFrame([{
        "metric": y_col,
        "model": model_name,
        "spear_rho": rho,
        "spear_p": spearman_p,
        "glm_slope": slope,
        "glm_p": slope_p,
    }])

# %% [markdown]
# ## Function 1: plot all groups

# %%
def plot_scatter_grid(
    df, values, x, group_col, hue_palette,
    ncols=3, save_path=None, regress=False):

    nplots = len(values)
    nrows = (nplots + ncols - 1) // ncols
    figsize=(ncols*5, nrows*4)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)

    axes = axes.flatten()

    for k, v in enumerate(values):
        axi = axes[k]
        
        if 'HIGH' in values:
            dfi = df[(df['impact'] == v) & (df['state'] == 'hom')]
            y = 'number'
        else:
            dfi = df
            y = v
        
        if x == 'year':
            style = 'stage'
            markers_dict = {'adult': 'o', 'hatchling': 'v'}
        else:
            style = None
            markers_dict = None

        dfi = dfi[['sample', x, y, group_col, 'stage']].drop_duplicates()
        
        sns.scatterplot(
            ax=axi, data=dfi, x=x, y=y, hue=group_col,
            alpha=0.8, edgecolor='k', linewidth=0.2, 
            style=style, markers=markers_dict,
            palette=hue_palette)

        axi.set_title(v)
        axi.set_ylabel(f'{y}')
        axi.set_xlabel(x)
        
        if len(values) == 1 or (k % ncols) == (ncols - 1):
            sns.move_legend(axi, "upper left", bbox_to_anchor=(1, 1))
        else:
            axi.get_legend().set_visible(False)
 
        # Check regression
        if regress:
            stats_df = plot_glm(axi, dfi, group_col, x, y, palette=hue_palette)
            print(v)
            print(stats_df)

    # Hide any unused subplots
    for ax in axes[nplots:]:
        ax.axis('off')

    sns.despine()
    fig.tight_layout()

    if save_path:
        fig.savefig(save_path, bbox_inches='tight')

    return fig, axes

# %% [markdown]
# ## Function 2: plot main groups

# %%
def plot_scatter_main(
    df, values, x, group_col, group1, group2,
    hue_palette, pop_palette, ncols=3, save_path=None):
    
    pops = [group1, group2]
    df = df[df['group'].isin(pops)]

    nplots = len(values)
    nrows = (nplots + ncols - 1) // ncols
    figsize=(ncols*5, nrows*4)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    axes = axes.flatten()

    c1 = pop_palette[group1]
    c2 = pop_palette[group2]

    for k, v in enumerate(values):
        ax_main = axes[k]
        
        if 'HIGH' in values:
            dfi = df[(df['impact'] == v) & (df['state'] == 'hom')]
            y = 'number'
        else:
            dfi = df
            y = v
        
        # Subset for statistical test
        data1 = dfi[dfi['group'] == group1][y]
        data2 = dfi[dfi['group'] == group2][y]
        stat, pval = mannwhitneyu(data1, data2, alternative='two-sided')

        
        # !!!!!!! Check regression!!!!!
        stats_df = plot_regression(ax_main, dfi, 'group', x, y, palette=hue_palette)
        print(v)
        print(stats_df)
        
        if x.startswith('L') or x.startswith('F'):
            style = 'group'
            markers_dict = {'small_stable': 'o', 'larger_declining': 'v'}
        else:
            style = None
            markers_dict = None
            
        # Scatterplot
        sns.scatterplot(
            ax=ax_main, data=dfi, x=x, y=y, hue=group_col,
            alpha=0.8, edgecolor='k', linewidth=0.2, 
            style=style, markers=markers_dict, palette=hue_palette)

        ax_main.set_title(v)
        ax_main.set_xlabel(x)
        ax_main.set_ylabel(f'{y}')

        # Inset boxplot
        ax_inset = ax_main.inset_axes([1, 0, 0.14, 1])  # [x0, y0, width, height]
        sns.boxplot(
            ax=ax_inset, data=dfi, y=y, x='group', boxprops=dict(alpha=.7),
            width=0.6, fliersize=0, linewidth=0.8, palette=pop_palette)
        
        ax_inset.set_xticks([])
        ax_inset.set_yticks([])
        ax_inset.set_xlabel('')
        ax_inset.set_ylabel('')
        ax_inset.set_frame_on(False)
        ax_inset.set_ylim(ax_main.get_ylim())

        # Annotate p-value
        ax_main.text(
            0.95, 0.95, f"p = {pval:.2e}", ha='center', va='top',
            fontsize=9, transform=ax_main.transAxes)

        # Legend
        if len(values) == 1 or (k % ncols) == (ncols - 1):
            sns.move_legend(ax_main, "upper left", bbox_to_anchor=(1.15, 1))
        else:
            ax_main.get_legend().set_visible(False)

    # Turn off any unused subplots
    for ax in axes[nplots:]:
        ax.axis('off')

    sns.despine()
    fig.tight_layout()

    if save_path:
        fig.savefig(save_path, bbox_inches='tight')

    return fig, axes

# %% [markdown]
# ## Function 3: boxplots

# %%
def plot_boxplots(
    df, values, x, group_col, hue_palette,
    ncols=3, save_path=None, regress=False):

    nplots = len(values)
    nrows = (nplots + ncols - 1) // ncols
    figsize=(ncols*3, nrows*3)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    axes = axes.flatten()

    global pop_order
    if x != 'group':
        pop_order = None

    for k, v in enumerate(values):
        axi = axes[k]
        
        if 'HIGH' in values:
            dfi = df[(df['impact'] == v) & (df['state'] == 'hom')]
            y = 'number'
        else:
            dfi = df
            y = v
            
        axi = axes[k]
        
        sns.boxplot(
            ax=axi, data=dfi, x=x, y=y, showfliers=False, color='#dddddd', order=pop_order)
        
        sns.stripplot(
            ax=axi, data=dfi, x=x, y=y, hue=group_col, order=pop_order,
            alpha=0.8, s=4, linewidth=0.1, palette=hue_palette)

        axi.set_title(y)
        axi.set_ylabel(f'{y}')
        axi.set_xlabel('')
        plt.setp(axi.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

        # Legend
        legend = axi.get_legend()
        if (len(values) == 1 or (k % ncols) == (ncols - 1)):
            if legend is not None:
                sns.move_legend(axi, "upper left", bbox_to_anchor=(1.15, 1))
        else:
            if legend is not None:
                legend.set_visible(False)
        
        # Check trend
        if regress:
            stats_df = test_trend(dfi, x, y)
            print(stats_df)

    # Hide any unused subplots
    for ax in axes[nplots:]:
        ax.axis('off')

    sns.despine()
    fig.tight_layout()

    if save_path:
        fig.savefig(save_path, bbox_inches='tight')

    return fig, axes

# %% [markdown]
# # 1. ROH analysis (PLINK)

# %% [markdown]
# ## 1.1. Load ROH data

# %%
dc = '222'
dir_path = '/Users/osipova/Documents/LabDocs/Leatherback_popgen/'
file_name = f'ROH_{dc}/all_samples_binned_ROH.tsv'
file_data = glob(dir_path + file_name)[0]
df_roh = pd.read_csv(file_data, sep='\t')

## ROH Lengths
df_roh['L_total'] = df_roh['L_less100'] + df_roh['L_100_500'] + df_roh['L_more500']
df_roh['L_less500'] = df_roh['L_total'] - df_roh['L_100_500']

## ROH numbers
df_roh['number_ROH'] = df_roh['N_less100'] + df_roh['N_100_500'] + df_roh['N_more500']
df_roh['L_ave'] = df_roh['L_total'] / df_roh['number_ROH']

## Assign location to each sample
df_all_roh = pd.merge(df_roh, INFO, on='sample')

df_all_roh['exclude'] = df_all_roh['exclude'].fillna('include')

## Calculate F_ROH = L_ROH/Lgenome, in kb!!
L_genome = 2_164_762.090
df_all_roh['F_ROH'] = df_all_roh['L_total'] / L_genome

# %% [markdown]
# ### Subset for chosen PLINK parameters

# %%
q = 20
round_q = 'from_Lisa_window_{}'.format(q)
df_all_roh = df_all_roh[df_all_roh['round'] == round_q]

# %% [markdown]
# ## 1.2. Merge with genetic load data from snpEff

# %%
file_name = f'snpEff_{dc}/all_samples.snp_indel_hom_het_by_impact.tsv'
file_data = glob(dir_path + file_name)[0]
df = pd.read_csv(file_data, sep='\t')

## Merge with snpEff data ---> this will be used in Temporal analysis later!
df_roh_merged = pd.merge(df_all_roh, df, on='sample')

## Main analysis: Exclude all samples the are not 'include'
df_roh_merged_include = df_roh_merged[df_roh_merged['exclude'] == 'include']
df_all_roh_include = df_roh_merged_include.copy()

# %% [markdown]
# ## 1.3. ROH values = f(depth):

# %%
x = 'depth'
values = ['number_ROH', 'L_total', 'L_ave', 'L_less100', 'L_100_500', 'L_more500']

plot_scatter_grid(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'ROH_by_class.{x}.all.pdf');

# %% [markdown]
# ## 1.4. ROH values = f(F_ROH)

# %%
x = 'F_ROH'
values = ['number_ROH', 'L_total', 'L_ave', 'L_less100', 'L_100_500', 'L_more500']

plot_scatter_grid(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'ROH_by_class.{x}.all.pdf');

# %% [markdown]
# ## 1.5. Number and length of ROHs by length class in each MU

# %%
x = 'group'
values = ['N_less100', 'N_100_500', 'N_more500']

plot_boxplots(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'N_ROH_by_class.{x}.all.pdf');

values = ['L_less100', 'L_100_500', 'L_more500']

plot_boxplots(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'L_ROH_by_class.{x}.all.pdf');

# %% [markdown]
# ## 1.6. ROH = f(F_ROH) main groups

# %%
x = 'F_ROH'
values = ['number_ROH', 'L_ave', 'L_total', 'L_less100', 'L_100_500', 'L_more500']

plot_scatter_main(
    df=df_all_roh_include,
    values=values,
    x=x,
    group1='larger_declining',
    group2='small_stable',
    group_col='MU',
    hue_palette=mu_palette_dict,
    pop_palette=population_palette_dict,
    save_path=f'ROH_by_class.{x}.L_S.pdf');
# Out:
# number_ROH
#               group        slope    intercept         r        r2  \
# 0  larger_declining  5744.118556  5229.708609  0.596887  0.356275
# 1      small_stable  5189.462942  5405.739227  0.424478  0.180181
#
#           pvalue      stderr
# 0  4.454208e-104  236.484489
# 1   2.985320e-30  431.532219
# L_ave
#               group       slope  intercept         r        r2         pvalue  \
# 0  larger_declining  209.794318  31.152651  0.873277  0.762612   0.000000e+00
# 1      small_stable  200.553612  35.870934  0.748040  0.559563  2.856731e-119
#
#      stderr
# 0  3.585024
# 1  6.936408
# L_total
#               group       slope     intercept    r   r2  pvalue  stderr
# 0  larger_declining  2164762.09 -3.492460e-10  1.0  1.0     0.0     0.0
# 1      small_stable  2164762.09  4.656613e-10  1.0  1.0     0.0     0.0
# L_less100
#               group          slope      intercept         r        r2  \
# 0  larger_declining -172388.959042  382735.452507 -0.306162  0.093735
# 1      small_stable -198001.515934  387117.597875 -0.275183  0.075726
#
#          pvalue        stderr
# 0  1.303802e-24  16417.528920
# 1  6.220116e-13  26967.058877
# L_100_500
#               group         slope      intercept         r        r2  pvalue  \
# 0  larger_declining  1.893632e+06 -239187.535235  0.976821  0.954179     0.0
# 1      small_stable  1.819637e+06 -199143.018719  0.982366  0.965043     0.0
#
#          stderr
# 0  12709.650045
# 1  13501.000622
# L_more500
#               group          slope      intercept         r        r2  \
# 0  larger_declining  443518.978595 -143547.917271  0.746694  0.557553
# 1      small_stable  543126.686908 -187974.579156  0.652352  0.425564
#
#           pvalue        stderr
# 0  5.737680e-191  12101.006095
# 1   2.936930e-81  24599.536149

# %% [markdown]
# ### What are the outlier Northeast Caribbean samples?

# %%
df_temp = df_all_roh_include.copy()
# df_temp = df_temp[df_temp['group'].isin(['larger_declining', 'small_stable', 'small_recovering'])]
df1 = df_temp[df_temp['MU'] == 'Northeast Caribbean']

fig, axes = plt.subplots(figsize=(5.5, 3.5))

sns.scatterplot(ax=axes, data=df_temp, x='L_total', y='number_ROH', 
                hue='group', linewidth=0, alpha=0.3, palette=population_palette_dict)
sns.scatterplot(ax=axes, data=df1, x='L_total', y='number_ROH', edgecolor='k', hue='year', s=65)

sns.move_legend(axes, "upper left", bbox_to_anchor=(1, 1))
sns.despine()
fig.tight_layout()
plt.show()

save_path = 'Northeast_Caribbean.ROHs_N_L_total.by_year.pdf'
# fig.savefig(save_path, bbox_inches='tight')

# %% [markdown]
# ## 1.7. ROH number 100-500 = f(L_ROH 100-500)

# %%
for x, values in [('L_total', ['number_ROH']),
                  ('L_less100', ['N_less100']), 
                  ('L_100_500', ['N_100_500']), 
                  ('L_more500', ['N_more500'])]:
# x = 'L_100_500'
# values = ['N_100_500']

    plot_scatter_grid(
        df=df_all_roh_include,
        values=values,
        x=x,
        group_col='MU',
        hue_palette=mu_palette_dict,
        save_path=f'ROH.{x}.all.pdf');

# %% [markdown]
# ## 1.8. Main groups ROH number 100-500 = f(L_ROH 100-500)

# %%
for x, values in [('L_total', ['number_ROH']),
                  ('L_less100', ['N_less100']), 
                  ('L_100_500', ['N_100_500']), 
                  ('L_more500', ['N_more500'])]:

    plot_scatter_main(
        df=df_all_roh_include,
        values=values,
        x=x,
        group1='larger_declining',
        group2='small_stable',
        group_col='MU',
        hue_palette=mu_palette_dict,
        pop_palette=population_palette_dict,
        save_path=f'ROH.{x}.L_S.pdf');
# Out:
# number_ROH
#               group     slope    intercept         r        r2         pvalue  \
# 0  larger_declining  0.002653  5229.708609  0.596887  0.356275  4.454208e-104
# 1      small_stable  0.002397  5405.739227  0.424478  0.180181   2.985320e-30
#
#      stderr
# 0  0.000109
# 1  0.000199
# N_less100
#               group     slope   intercept         r        r2  pvalue  \
# 0  larger_declining  0.014727 -114.177686  0.998041  0.996087     0.0
# 1      small_stable  0.014304  -16.162262  0.999095  0.998191     0.0
#
#      stderr
# 0  0.000028
# 1  0.000024
# N_100_500
#               group     slope   intercept         r        r2         pvalue  \
# 0  larger_declining  0.004156  821.097077  0.979796  0.959999   0.000000e+00
# 1      small_stable  0.004060  892.293776  0.941869  0.887117  6.819625e-314
#
#      stderr
# 0  0.000026
# 1  0.000056
# N_more500
#               group     slope  intercept         r        r2  pvalue    stderr
# 0  larger_declining  0.001403   3.499933  0.997091  0.994190     0.0  0.000003
# 1      small_stable  0.001420   6.261252  0.997846  0.995697     0.0  0.000004

# %% [markdown]
# ## F_ROH boxplots each MU

# %%
x = 'MU'
values = ['F_ROH']

plot_boxplots(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'F_ROH.boxplot.{x}.all.pdf');

# %% [markdown]
# ## F_ROH boxplots all groups

# %%
x = 'group'
values = ['F_ROH']

plot_boxplots(
    df=df_all_roh_include,
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'F_ROH.boxplot.{x}.all.pdf');

g1 = 'larger_declining'
g2 = 'small_stable'
x = 'group'
y = 'F_ROH'

# Subset for statistical test
data1 = df_all_roh[df_all_roh[x] == g1][y]
data2 = df_all_roh[df_all_roh[x] == g2][y]
stat, pval = mannwhitneyu(data1, data2, alternative='two-sided')
print(pval)
# Out:
# 6.650354696762981e-09

# %% [markdown]
# # 2. Genetic load = f(ROH)

# %% [markdown]
# ## 2.1. Number of homs by impact = f(F_ROH)
# #### Consider only SNPs (exclude indels)

# %%
x = 'F_ROH'
impacts = ['HIGH', 'MODERATE', 'LOW']

plot_scatter_grid(
    df=df_roh_merged_include,
    values=impacts,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'homs_by_impact.{x}.all.pdf');

# %% [markdown]
# ## 2.2. Main groups: Number of homs by impact = f(F_ROH)

# %%
x = 'F_ROH'
impacts = ['HIGH', 'MODERATE', 'LOW']

plot_scatter_main(
    df=df_roh_merged_include,
    values=impacts,
    x=x,
    group1='larger_declining',
    group2='small_stable',
    group_col='MU',
    hue_palette=mu_palette_dict,
    pop_palette=population_palette_dict,
    save_path=f'new.homs_by_impact.{x}.L_S.pdf');
# Out:
# HIGH
#               group      slope   intercept         r        r2    pvalue  \
# 0  larger_declining  12.657255  122.038714  0.066993  0.004488  0.532774
# 1      small_stable  29.035397  122.472862  0.125056  0.015639  0.362972
#
#       stderr
# 0  20.210364
# 1  31.641881
# MODERATE
#               group        slope    intercept         r        r2    pvalue  \
# 0  larger_declining  1180.205805  2172.054172  0.341377  0.116538  0.001061
# 1      small_stable  1800.579102  2098.563955  0.381905  0.145851  0.004013
#
#        stderr
# 0  348.383473
# 1  598.530014
# LOW
#               group        slope    intercept         r        r2    pvalue  \
# 0  larger_declining  1913.458814  2443.017598  0.400101  0.160081  0.000102
# 1      small_stable  3298.501272  2124.637679  0.508017  0.258081  0.000075
#
#        stderr
# 0  469.903849
# 1  768.207698

# %% [markdown]
# ## 2.3. Main groups: Number of homs by impact = f(ROHs by length class)

# %%
values = ['L_less100', 'L_100_500', 'L_more500']
for x in values:
    impacts = ['HIGH', 'MODERATE', 'LOW']

    plot_scatter_main(
        df=df_roh_merged_include,
        values=impacts,
        x=x,
        group1='larger_declining',
        group2='small_stable',
        group_col='MU',
        hue_palette=mu_palette_dict,
        pop_palette=population_palette_dict,
        save_path=f'homs_by_impact.{x}.L_S.pdf');

# %% [markdown]
# # 3. Temporal analysis

# %% [markdown]
# ## 3.1. ROH = f(t) Mexico and Virgin Islands (scatterplot)

# %%
values = ['L_less100', 'L_100_500', 'L_more500', 'number_ROH', 'F_ROH']
group = 'rookery'
x = 'year'

## Include only samples for the temporal analsyis

# temporal_groups = ['Mexico', 'Virgin Islands', 'Indonesia']
# temporal_groups = ['Mexico', 'Virgin Islands']
# df = df_roh_merged[df_roh_merged[group].isin(temporal_groups)]
df = df_roh_merged[df_roh_merged['temporal'] == 'include']
df['stage'] = df['stage'].fillna('adult')

plot_scatter_grid(
    df=df.dropna(subset=[x]),
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'temporal.ROH.{x}.pdf',
    regress=True);
# Out:
# L_less100
#                  group   slope_year    p_year  p_C(stage)[T.hatchling]
# 0      Eastern Pacific  -499.012047  0.343791                 0.515446
# 1  Northeast Caribbean  3566.635619  0.031148                 0.000004
# L_100_500
#                  group   slope_year    p_year  p_C(stage)[T.hatchling]
# 0      Eastern Pacific  1950.633020  0.241354                 0.559778
# 1  Northeast Caribbean -6117.748802  0.141773                 0.366519
# L_more500
#                  group   slope_year    p_year  p_C(stage)[T.hatchling]
# 0      Eastern Pacific   408.784691  0.421924                 0.503665
# 1  Northeast Caribbean -5554.907105  0.043929                 0.000151
# number_ROH
#                  group  slope_year    p_year  p_C(stage)[T.hatchling]
# 0      Eastern Pacific    0.013911  0.998681             9.872646e-01
# 1  Northeast Caribbean   30.558958  0.062426             6.201207e-12
# F_ROH
#                  group  slope_year    p_year  p_C(stage)[T.hatchling]
# 0      Eastern Pacific    0.003635  0.301165                 0.604452
# 1  Northeast Caribbean   -0.015116  0.120035                 0.218729

# %% [markdown]
# ## 3.2. ROH = f(generation!) Mexico and Virgin Islands (boxplots)

# %%
x = 'generation'
values = ['L_less100', 'L_100_500', 'L_more500', 'number_ROH', 'F_ROH']
group = 'rookery'

df = df_roh_merged[df_roh_merged['temporal'] == 'include']
df['stage'] = df['stage'].fillna('adult')
df = df[values + [group, x, 'MU']].drop_duplicates()

temporal_groups = ['Mexico', 'Virgin Islands']

for i in temporal_groups:
    print(i)
    plot_boxplots(
        df=df[df[group] == i],
        values=values,
        x=x,
        group_col='MU',
        hue_palette=mu_palette_dict,
        regress=True,
        save_path=f'temporal.ROH.boxplot.{x}.{i}.pdf');
# Out:
# Mexico
#       metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  L_less100  Gamma  -0.310805  0.045136  -0.045984  0.037541
#       metric  model  spear_rho   spear_p  glm_slope    glm_p
# 0  L_100_500  Gamma   0.436251  0.003875   0.103361  0.00673
#       metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  L_more500  Gamma   0.416661  0.006054   0.473191  0.003819
#        metric              model  spear_rho   spear_p  glm_slope     glm_p
# 0  number_ROH  Negative Binomial  -0.028902  0.855825   0.005329  0.980004
#   metric           model  spear_rho   spear_p  glm_slope     glm_p
# 0  F_ROH  logit Binomial    0.43836  0.003688   0.125208  0.769468
# Virgin Islands
#       metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  L_less100  Gamma  -0.474434  0.002618  -0.095067  0.001721
#       metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  L_100_500  Gamma  -0.006891  0.967249  -0.013588  0.657319
#       metric  model  spear_rho  spear_p  glm_slope     glm_p
# 0  L_more500  Gamma    0.43947  0.00577   0.344797  0.033035
#        metric              model  spear_rho   spear_p  glm_slope     glm_p
# 0  number_ROH  Negative Binomial  -0.653846  0.000009  -0.065484  0.761562
#   metric           model  spear_rho   spear_p  glm_slope     glm_p
# 0  F_ROH  logit Binomial   0.117907  0.480804  -0.004581  0.991548

# %% [markdown]
# ## 3.3. Genetic load (homs) = f(t) Mexico and Virgin Islands (scatterplots)

# %%
values = ['HIGH', 'MODERATE', 'LOW']
group = 'rookery'
x = 'year'

plot_scatter_grid(
    df=df.dropna(subset=[x]),
    values=values,
    x=x,
    group_col='MU',
    hue_palette=mu_palette_dict,
    save_path=f'temporal.homs_by_impact.{x}.pdf',
    regress=True);
# Out:
# HIGH
#                  group  slope_year    p_year  p_C(stage)[T.hatchling]
# 0  Northeast Caribbean    -0.62103  0.065165                 0.838552
# 1      Eastern Pacific     0.01548  0.928113                 0.543888
# MODERATE
#                  group  slope_year    p_year  p_C(stage)[T.hatchling]
# 0  Northeast Caribbean   -0.250363  0.971076                 0.064894
# 1      Eastern Pacific    4.529791  0.064924                 0.699428
# LOW
#                  group  slope_year    p_year  p_C(stage)[T.hatchling]
# 0  Northeast Caribbean   -2.984949  0.761737                 0.079736
# 1      Eastern Pacific    7.107410  0.005964                 0.488071

# %% [markdown]
# ## 3.4. Genetic load (homs) = f(generations!) Mexico and Virgin Islands (boxplots)

# %%
values = ['HIGH', 'MODERATE', 'LOW']
group = 'rookery'
x = 'generation'

df = df_roh_merged[df_roh_merged['temporal'] == 'include']
df['stage'] = df['stage'].fillna('adult')
df = df[['impact', 'state', 'number', group, x, 'MU']].drop_duplicates()

temporal_groups = ['Mexico', 'Virgin Islands']

for i in temporal_groups:
    print(i)
    plot_boxplots(
        df=df[df[group] == i],
        values=values,
        x=x,
        group_col='MU',
        hue_palette=mu_palette_dict,
        regress=True,
        save_path=f'temporal.homs_by_impact.boxplot.{x}.{i}.pdf');
# Out:
# Mexico
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma  -0.124432  0.450409  -0.012975  0.450978
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma   0.138898  0.380344    0.01063  0.283966
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma   0.165415  0.314242   0.014028  0.131271
# Virgin Islands
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma  -0.295253  0.127175  -0.021405  0.081757
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma  -0.383004  0.017624  -0.022169  0.032222
#    metric  model  spear_rho   spear_p  glm_slope     glm_p
# 0  number  Gamma  -0.390971  0.016726  -0.029453  0.013179

# %% [markdown]
# ## 4. Distribution of all ROHs

# %%
FILE = 'ROH_222/ROHs_all.MUs.tsv'
df = pd.read_csv(FILE, sep="\t")

GROUPS = ['larger_declining','small_stable']
df['exclude'] = df['exclude'].fillna('include')
dfi = df[df['group'].isin(GROUPS)]
dfi = dfi[dfi['exclude'] == 'include']

dfi.head(3)
# Out:
#         sample               MU           rookery             group  exclude  \
# 66702  Z026452  Western Pacific  Papua New Guinea  larger_declining  include
# 66703  Z026452  Western Pacific  Papua New Guinea  larger_declining  include
# 66704  Z026452  Western Pacific  Papua New Guinea  larger_declining  include
#
#            roh
# 66702  105.044
# 66703  105.591
# 66704  154.572

# %%
# dfi = dfi[dfi['group'] == 'small_stable']
dfi = dfi[dfi['roh'] >1000]

mus = sorted(dfi['MU'].unique())   # 4 MUs

fig, axes = plt.subplots(1, 5, figsize=(11, 5), sharey=True)

for ax, mu in zip(axes, mus):
    dfi_mu = dfi[dfi['MU'] == mu].copy()
    
    # number of *samples* in this MU
    n_samples_mu = dfi_mu['sample'].nunique()
    
    # weight each row so that total weight per MU = 1
    dfi_mu['w_sample_norm'] = 1.0 / n_samples_mu

    sns.histplot(
        data=dfi_mu,
        x='roh',
#         binwidth=50,
        common_norm=False,
        weights=dfi_mu['w_sample_norm'],
        alpha=0.3,
        color=mu_palette_dict[mu],
        ax=ax
    )
    
    ax.set_title(mu)
    if ax.get_legend() is not None:
        ax.get_legend().remove()

sns.despine()
fig.tight_layout()
plt.show()
